# %% [markdown]
# Important packages to be installed

# %%
# !pip install tensorflow==2.17.0 opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.17.0 in c:\users\amartya\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: opencv-python in c:\users\amartya\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\amartya\anaconda3\lib\site-packages (0.10.14)
# Requirement already satisfied: scikit-learn in c:\users\amartya\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib in c:\users\amartya\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow==2.17.0) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\amartya\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\amartya\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: jax in c:\users\amartya\anaconda3\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: jaxlib in c:\users\amartya\anaconda3\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: opencv-contrib-python in c:\users\amartya\anaconda3\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\amartya\anaconda3\lib\site-packages (from mediapipe) (0.4.7)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\amartya\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\amartya\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amartya\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amartya\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: CFFI>=1.0 in c:\users\amartya\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\amartya\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.41.2)
# Requirement already satisfied: pycparser in c:\users\amartya\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: rich in c:\users\amartya\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (13.3.5)
# Requirement already satisfied: namex in c:\users\amartya\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.0.8)
# Requirement already satisfied: optree in c:\users\amartya\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amartya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amartya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amartya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amartya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\amartya\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\amartya\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\amartya\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\amartya\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\amartya\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\amartya\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amartya\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.1.0)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# Keypoints using MP holistic

# %%
mp_holistic = mp.solutions.holistic           #Holistic model
mp_drawing = mp.solutions.drawing_utils        #Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)         #color conversion
    image.flags.writeable = False              #image is no longer writeable
    results = model.process(image)             #make prediction
    image.flags.writeable = True               #making image writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)             #color conversion
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)        #face connection
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)         #pose connection
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)      #hand cconnection
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)          #hand connection

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))     #face connection
    
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))         #pose connection
    
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))      #hand cconnection
    
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))          #hand connection

# %%
cap = cv2.VideoCapture(0)
#set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        #read feed
        ret,frame = cap.read()
        #make detection
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        #draw landmarks
        draw_styled_landmarks(image, results)
        #display result
        cv2.imshow("OpenCV feed", image)
    
        #break loop
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# C:\Users\Amartya\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
len(results.pose_landmarks.landmark)
# Out:
# 33

# %%
frame
# Out:
# array([[[168, 172, 123],
#         [167, 171, 123],
#         [167, 169, 126],
#         ...,
#         [178, 178, 128],
#         [179, 178, 128],
#         [178, 177, 127]],
#
#        [[168, 174, 123],
#         [167, 172, 123],
#         [167, 171, 126],
#         ...,
#         [177, 178, 128],
#         [178, 178, 128],
#         [178, 177, 127]],
#
#        [[170, 178, 124],
#         [168, 175, 124],
#         [169, 175, 127],
#         ...,
#         [178, 179, 129],
#         [178, 178, 128],
#         [178, 177, 127]],
#
#        ...,
#
#        [[ 62,  71,  82],
#         [ 65,  74,  85],
#         [ 70,  79,  89],
#         ...,
#         [113, 124,  85],
#         [113, 126,  85],
#         [113, 127,  85]],
#
#        [[ 62,  72,  82],
#         [ 66,  76,  86],
#         [ 71,  82,  90],
#         ...,
#         [113, 122,  82],
#         [113, 125,  83],
#         [112, 125,  83]],
#
#        [[ 60,  71,  79],
#         [ 65,  76,  84],
#         [ 71,  82,  90],
#         ...,
#         [113, 122,  82],
#         [114, 125,  83],
#         [113, 125,  83]]], dtype=uint8)

# %%
draw_landmarks(frame,results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
len(results.pose_landmarks.landmark)
# Out:
# 33

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark])
# Out:
# 33
